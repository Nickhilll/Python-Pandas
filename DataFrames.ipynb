# %% [markdown]
# ## DataFrames Session 1

# %% [markdown]
# ![image.png](attachment:a9bef784-5367-4906-b80d-8e3ff4ff05a3.png)

# %%
import pandas as pd

# %%
dict = {
    "Name" : ["Nikhil", "Akash", "Vinod", "Priya", "Anjali"],
    "Age" : [20,21,19,20,22],
    "Marks": [85.10, 77.80, 91.54, 88.78, 60.55],
    "Grade": ["A","B","A", "B","A"],
    "Hobby": ["Swimming", "Reading", "Photography", "Painting", "Dancing"]
}
type(dict)
# Out:
# dict

# %%
dict
# Out:
# {'Name': ['Nikhil', 'Akash', 'Vinod', 'Priya', 'Anjali'],
#  'Age': [20, 21, 19, 20, 22],
#  'Marks': [85.1, 77.8, 91.54, 88.78, 60.55],
#  'Grade': ['A', 'B', 'A', 'B', 'A'],
#  'Hobby': ['Swimming', 'Reading', 'Photography', 'Painting', 'Dancing']}

# %%
Data = pd.DataFrame(dict)
Data
# Out:
#      Name  Age  Marks Grade        Hobby
# 0  Nikhil   20  85.10     A     Swimming
# 1   Akash   21  77.80     B      Reading
# 2   Vinod   19  91.54     A  Photography
# 3   Priya   20  88.78     B     Painting
# 4  Anjali   22  60.55     A      Dancing

# %%
Data.shape
# Out:
# (5, 5)

# %%
Data = pd.DataFrame(dict, index = ["s1", "s2", "s3", "s4","s5"])
Data
# Out:
#       Name  Age  Marks Grade        Hobby
# s1  Nikhil   20  85.10     A     Swimming
# s2   Akash   21  77.80     B      Reading
# s3   Vinod   19  91.54     A  Photography
# s4   Priya   20  88.78     B     Painting
# s5  Anjali   22  60.55     A      Dancing

# %% [markdown]
# ### 2.Creating data Frame with list

# %%
s1 = ["Nikhil", 20, 85.10, "A", "Swimming"]
s2 = ["Akash", 21, 77.80, "B", "Reading"]
s3 = ["Vinod", 19, 91.80, "A", "Photography"]
s4 = ["Priya", 20, 88.78, "B", "Painting"]
s5 = ["Anjali", 22, 60.55, "A", "Dancing"]

# %%
type(s1)
# Out:
# list

# %%
d = pd.DataFrame([s1,s2,s3,s4,s5])
d
# Out:
#         0   1      2  3            4
# 0  Nikhil  20  85.10  A     Swimming
# 1   Akash  21  77.80  B      Reading
# 2   Vinod  19  91.80  A  Photography
# 3   Priya  20  88.78  B     Painting
# 4  Anjali  22  60.55  A      Dancing

# %%
E = pd.DataFrame(
    [s1,s2,s3,s4,s5],
    columns = ["Name", "Age","Marks", "Grade", "Hobby"],
    index = ["s1","s2","s3","s4","s5"]
)

# %%
E
# Out:
#       Name  Age  Marks Grade        Hobby
# s1  Nikhil   20  85.10     A     Swimming
# s2   Akash   21  77.80     B      Reading
# s3   Vinod   19  91.80     A  Photography
# s4   Priya   20  88.78     B     Painting
# s5  Anjali   22  60.55     A      Dancing

# %% [markdown]
# ## Attributes of DataFrames

# %% [markdown]
# #### 1.shape->(num_rows, num_rows)
# #### 2.Columns.
# #### 3.index.
# #### 4.dtypes.
# #### 5.Values

# %%
E
# Out:
#       Name  Age  Marks Grade        Hobby
# s1  Nikhil   20  85.10     A     Swimming
# s2   Akash   21  77.80     B      Reading
# s3   Vinod   19  91.80     A  Photography
# s4   Priya   20  88.78     B     Painting
# s5  Anjali   22  60.55     A      Dancing

# %%
E.shape
# Out:
# (5, 5)

# %%
E.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'Grade', 'Hobby'], dtype='object')

# %%
E.index
# Out:
# Index(['s1', 's2', 's3', 's4', 's5'], dtype='object')

# %%
E.dtypes
# Out:
# Name      object
# Age        int64
# Marks    float64
# Grade     object
# Hobby     object
# dtype: object

# %%
E.values
# Out:
# array([['Nikhil', 20, 85.1, 'A', 'Swimming'],
#        ['Akash', 21, 77.8, 'B', 'Reading'],
#        ['Vinod', 19, 91.8, 'A', 'Photography'],
#        ['Priya', 20, 88.78, 'B', 'Painting'],
#        ['Anjali', 22, 60.55, 'A', 'Dancing']], dtype=object)

# %% [markdown]
# ### String is represented as object datatype in pandas dataFrame

# %%
E.values
# Out:
# array([['Nikhil', 20, 85.1, 'A', 'Swimming'],
#        ['Akash', 21, 77.8, 'B', 'Reading'],
#        ['Vinod', 19, 91.8, 'A', 'Photography'],
#        ['Priya', 20, 88.78, 'B', 'Painting'],
#        ['Anjali', 22, 60.55, 'A', 'Dancing']], dtype=object)

# %%
num_rows = E

# %%
num_rows, num_cols = E.shape

# %%
num_rows
# Out:
# 5

# %%
num_cols
# Out:
# 5

# %% [markdown]
# ### Functions/dataframes for columns
# ##### Function always ends with paranthesis ()

# %%
E.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, s1 to s5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      float64
#  3   Grade   5 non-null      object
#  4   Hobby   5 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 240.0+ bytes

# %% [markdown]
# ## To read Csv File

# %%
import pandas as pd 
## iloc Stands for Index location

# %%
DataSet = pd.read_csv(r"C:\Users\Nikhil\Desktop\Python folder\50_Startups.csv")
DataSet
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
DataSet.shape
# Out:
# (50, 5)

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
DataSet.values
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York', 192261.83],
#        [162597.7, 151377.59, 443898.53, 'California', 191792.06],
#        [153441.51, 101145.55, 407934.54, 'Florida', 191050.39],
#        [144372.41, 118671.85, 383199.62, 'New York', 182901.99],
#        [142107.34, 91391.77, 366168.42, 'Florida', 166187.94],
#        [131876.9, 99814.71, 362861.36, 'New York', 156991.12],
#        [134615.46, 147198.87, 127716.82, 'California', 156122.51],
#        [130298.13, 145530.06, 323876.68, 'Florida', 155752.6],
#        [120542.52, 148718.95, 311613.29, 'New York', 152211.77],
#        [123334.88, 108679.17, 304981.62, 'California', 149759.96],
#        [101913.08, 110594.11, 229160.95, 'Florida', 146121.95],
#        [100671.96, 91790.61, 249744.55, 'California', 144259.4],
#        [93863.75, 127320.38, 249839.44, 'Florida', 141585.52],
#        [91992.39, 135495.07, 252664.93, 'California', 134307.35],
#        [119943.24, 156547.42, 256512.92, 'Florida', 132602.65],
# ...

# %%
DataSet.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
DataSet.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
DataSet[["MKT"]]
# Out:
#           MKT
# 0   471784.10
# 1   443898.53
# 2   407934.54
# 3   383199.62
# 4   366168.42
# 5   362861.36
# 6   127716.82
# 7   323876.68
# 8   311613.29
# 9   304981.62
# 10  229160.95
# 11  249744.55
# 12  249839.44
# 13  252664.93
# 14  256512.92
# 15  261776.23
# 16  264346.06
# 17  282574.31
# 18  294919.57
# 19       0.00
# 20  298664.47
# 21  299737.29
# 22  303319.26
# 23  304768.73
# 24  140574.81
# 25  137962.62
# 26  134050.07
# 27  353183.81
# 28  118148.20
# 29  107138.38
# 30   91131.24
# 31   88218.23
# 32   46085.25
# 33  214634.81
# 34  210797.67
# 35  205517.64
# 36  201126.82
# 37  197029.42
# 38  185265.10
# 39  174999.30
# 40  172795.67
# 41  164470.71
# 42  148001.11
# 43   35534.17
# 44   28334.72
# 45    1903.93
# 46  297114.46
# 47       0.00
# 48       0.00
# 49   45173.06

# %% [markdown]
# ### Data Subsetting (iloc is for Number)(loc is for label(String))
# #### 1.Get any particular rows.
# #### 2.Get any particular columns.
# #### 3.Subsetting rows and columns.

# %%
DataSet.loc[[44,41,48],:]
# Out:
#          RND      ADMIN        MKT       STATE    PROFIT
# 44  22177.74  154806.14   28334.72  California  65200.33
# 41  27892.92   84710.77  164470.71     Florida  77798.83
# 48    542.05   51743.15       0.00    New York  35673.41

# %% [markdown]
# ## Methods for data Subsetting]

# %% [markdown]
# ### 1.df.iloc[row_index, columns_index]
# ### 2.df.loc[row_label, column_label]

# %% [markdown]
# ### Subsetting columns

# %%
DataSet[["ADMIN"]]
# Out:
#         ADMIN
# 0   136897.80
# 1   151377.59
# 2   101145.55
# 3   118671.85
# 4    91391.77
# 5    99814.71
# 6   147198.87
# 7   145530.06
# 8   148718.95
# 9   108679.17
# 10  110594.11
# 11   91790.61
# 12  127320.38
# 13  135495.07
# 14  156547.42
# 15  122616.84
# 16  121597.55
# 17  145077.58
# 18  114175.79
# 19  153514.11
# 20  113867.30
# 21  153773.43
# 22  122782.75
# 23  105751.03
# 24   99281.34
# 25  139553.16
# 26  144135.98
# 27  127864.55
# 28  182645.56
# 29  153032.06
# 30  115641.28
# 31  152701.92
# 32  129219.61
# 33  103057.49
# 34  157693.92
# 35   85047.44
# 36  127056.21
# 37   51283.14
# 38   65947.93
# 39   82982.09
# 40  118546.05
# 41   84710.77
# 42   96189.63
# 43  127382.30
# 44  154806.14
# 45  124153.04
# 46  115816.21
# 47  135426.92
# 48   51743.15
# 49  116983.80

# %%
type(DataSet["ADMIN"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Get RND, ADMIN and STATE columns

# %%
DataSet[["RND", "ADMIN", "STATE"]]
# Out:
#           RND      ADMIN       STATE
# 0   165349.20  136897.80    New York
# 1   162597.70  151377.59  California
# 2   153441.51  101145.55     Florida
# 3   144372.41  118671.85    New York
# 4   142107.34   91391.77     Florida
# 5   131876.90   99814.71    New York
# 6   134615.46  147198.87  California
# 7   130298.13  145530.06     Florida
# 8   120542.52  148718.95    New York
# 9   123334.88  108679.17  California
# 10  101913.08  110594.11     Florida
# 11  100671.96   91790.61  California
# 12   93863.75  127320.38     Florida
# 13   91992.39  135495.07  California
# 14  119943.24  156547.42     Florida
# 15  114523.61  122616.84    New York
# 16   78013.11  121597.55  California
# 17   94657.16  145077.58    New York
# 18   91749.16  114175.79     Florida
# 19   86419.70  153514.11    New York
# 20   76253.86  113867.30  California
# 21   78389.47  153773.43    New York
# 22   73994.56  122782.75     Florida
# 23   67532.53  105751.03     Florida
# ...

# %% [markdown]
# ## Subsetting rows

# %% [markdown]
# #### iloc["row_index", :]
# #### loc["row_index", :]

# %%
## Get the row index of 10
DataSet.iloc[[10],:]
# Out:
#           RND      ADMIN        MKT    STATE     PROFIT
# 10  101913.08  110594.11  229160.95  Florida  146121.95

# %% [markdown]
# ![image.png](attachment:ff05bb51-0e56-4018-b0e0-40f56faa066e.png)

# %%
DataSet.iloc[3:9, :]
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94
# 5  131876.90   99814.71  362861.36    New York  156991.12
# 6  134615.46  147198.87  127716.82  California  156122.51
# 7  130298.13  145530.06  323876.68     Florida  155752.60
# 8  120542.52  148718.95  311613.29    New York  152211.77

# %% [markdown]
# ## In case of loc method provide start and stop values directly

# %%
DataSet.iloc[3:8, :]
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94
# 5  131876.90   99814.71  362861.36    New York  156991.12
# 6  134615.46  147198.87  127716.82  California  156122.51
# 7  130298.13  145530.06  323876.68     Florida  155752.60

# %%
DataSet.iloc[[3,4], 3:]
# Out:
#       STATE     PROFIT
# 3  New York  182901.99
# 4   Florida  166187.94

# %%
DataSet.loc[[4,5],:]
# Out:
#          RND     ADMIN        MKT     STATE     PROFIT
# 4  142107.34  91391.77  366168.42   Florida  166187.94
# 5  131876.90  99814.71  362861.36  New York  156991.12

# %%
DataSet.loc[[5], "STATE":]
# Out:
#       STATE     PROFIT
# 5  New York  156991.12

# %%
DataSet.loc[[7], "PROFIT":]
# Out:
#      PROFIT
# 7  155752.6

# %%
DataSet.iloc[[13,4,8,7,5], :]
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 13   91992.39  135495.07  252664.93  California  134307.35
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 5   131876.90   99814.71  362861.36    New York  156991.12

# %% [markdown]
# ### SubSet of both rows and columns

# %% [markdown]
# #### 1.df.iloc[row_index, column_index]
# #### 2.df.loc[row_label, column_label]

# %% [markdown]
# ![image.png](attachment:924dcda6-b5dc-4a78-871e-07471d0d3dbd.png)

# %%
DataSet.iloc[5,2]
# Out:
# 362861.36

# %%
DataSet.iloc[7,1]
# Out:
# 145530.06

# %%
DataSet.loc[5, "STATE"]
# Out:
# 'New York'

# %% [markdown]
# ![image.png](attachment:c2aaa5be-8441-43c0-98b0-c10efdbdfb1c.png)

# %%
DataSet.iloc[2:7, 1:4]
# Out:
#        ADMIN        MKT       STATE
# 2  101145.55  407934.54     Florida
# 3  118671.85  383199.62    New York
# 4   91391.77  366168.42     Florida
# 5   99814.71  362861.36    New York
# 6  147198.87  127716.82  California

# %%
DataSet.loc[2:6, "ADMIN":"STATE"]
# Out:
#        ADMIN        MKT       STATE
# 2  101145.55  407934.54     Florida
# 3  118671.85  383199.62    New York
# 4   91391.77  366168.42     Florida
# 5   99814.71  362861.36    New York
# 6  147198.87  127716.82  California

# %%
DataSet.iloc[[3,7,6,9,10], [0, 2]]
# Out:
#           RND        MKT
# 3   144372.41  383199.62
# 7   130298.13  323876.68
# 6   134615.46  127716.82
# 9   123334.88  304981.62
# 10  101913.08  229160.95

# %%
DataSet.loc[[3,7,6,9,10], ["ADMIN", "PROFIT", "STATE"]]
# Out:
#         ADMIN     PROFIT       STATE
# 3   118671.85  182901.99    New York
# 7   145530.06  155752.60     Florida
# 6   147198.87  156122.51  California
# 9   108679.17  149759.96  California
# 10  110594.11  146121.95     Florida
